# %%
# !streamlit run streamlit_app_1-Copy1.py

# %%
import pandas as pd

# Assuming your DataFrame is named df
df = pd.read_csv('manual_analysation.csv')
filtered_df = df[
    ((df['FRS_ACCOUNT_CLASS'].str.contains("MULTIPROD")) & 
     (df['OPER_DPST_FLAG'].str.contains("N")) & 
     (df['ACTG_UNIT_NM'].str.contains("Account Sum of CR Transactions")) & 
     (df['ACCT_TYP'].str.contains("S")) & 
     (df['LV_DMC_CTRY'].str.contains("SG")) & 
     (df['ROW_SRC_IND'].str.contains("C")) & 
     (df['TXN_CCY'].str.contains("TWD")) & 
     (df['IB_FLAG'].str.contains("N"))) |
    ((df['FRS_ACCOUNT_CLASS'].str.contains("MULTIPROD")) & 
     (df['OPER_DPST_FLAG'].str.contains("N")) & 
     (df['ACTG_UNIT_NM'].str.contains("Trans Notional Payable \(FS\)")) & 
     (df['ACCT_TYP'].str.contains("S")) & 
     (df['LV_DMC_CTRY'].str.contains("JE")) & 
     (df['ROW_SRC_IND'].str.contains("PPSL")) & 
     (((df['TXN_CCY'].str.contains('GBP')) & (df['IB_FLAG'].str.contains('N'))) | 
      ((df['TXN_CCY'].str.contains('NZD')) & (df['IB_FLAG'].str.contains('N'))))) |
    ((df['FRS_ACCOUNT_CLASS'].str.contains("MULTIPROD")) & 
     (df['OPER_DPST_FLAG'].str.contains("N")) & 
     (df['ACTG_UNIT_NM'].str.contains("Trans Notional Recvable \(FS\)")) & 
     (df['ACCT_TYP'].str.contains("S")) & 
     (df['LV_DMC_CTRY'].str.contains("GB")) & 
     (df['ROW_SRC_IND'].str.contains("PPSL")) & 
     (df['TXN_CCY'].str.contains("USD")) & 
     (df['IB_FLAG'].str.contains("Y"))) |
    ((df['FRS_ACCOUNT_CLASS'].str.contains("MULTIPROD")) & 
     (df['OPER_DPST_FLAG'].str.contains("N")) & 
     (df['ACTG_UNIT_NM'].str.contains("Transfer Pricing P&L")) & 
     (df['ACCT_TYP'].str.contains("R")) & 
     (df['LV_DMC_CTRY'].str.contains("TW")) & 
     (df['ROW_SRC_IND'].str.contains("PPSL")) & 
     (df['TXN_CCY'].str.contains("TWD")) & 
     (df['IB_FLAG'].str.contains("Y"))) |
    ((df['FRS_ACCOUNT_CLASS'].str.contains("OVDFT-LIAB")) & 
     (df['OPER_DPST_FLAG'].str.contains("N")) & 
     (df['ACTG_UNIT_NM'].str.contains("Inventory Position Amount")) & 
     (df['ACCT_TYP'].str.contains("L")) & 
     (df['LV_DMC_CTRY'].str.contains("LU")) & 
     (df['ROW_SRC_IND'].str.contains("PPSL")) & 
     (df['TXN_CCY'].str.contains("TWD")) & 
     (df['IB_FLAG'].str.contains("N"))) |
    ((df['FRS_ACCOUNT_CLASS'].str.contains("OVDFT-LIAB")) & 
     (df['OPER_DPST_FLAG'].str.contains("N")) & 
     (df['ACTG_UNIT_NM'].str.contains("Inventory Position Amount")) & 
     (df['ACCT_TYP'].str.contains("L")) & 
     (df['LV_DMC_CTRY'].str.contains("SG")) & 
     (df['ROW_SRC_IND'].str.contains("PPSL")) & 
     (df['TXN_CCY'].str.contains("KRW")) & 
     (df['IB_FLAG'].str.contains("N"))) |
    ((df['FRS_ACCOUNT_CLASS'].str.contains("OVDFT-LIAB")) & 
     (df['OPER_DPST_FLAG'].str.contains("N")) & 
     (df['ACTG_UNIT_NM'].str.contains("Inventory Position Amount")) & 
     (df['ACCT_TYP'].str.contains("L")) & 
     (df['LV_DMC_CTRY'].str.contains("TH")) & 
     (df['ROW_SRC_IND'].str.contains("PPSL")) & 
     (df['TXN_CCY'].str.contains("THB")) & 
     (df['IB_FLAG'].str.contains("N"))) |
    ((df['FRS_ACCOUNT_CLASS'].str.contains("OVDFT-LIAB")) & 
     (df['OPER_DPST_FLAG'].str.contains("Y")) & 
     (df['ACTG_UNIT_NM'].str.contains("Inventory Position Amount")) & 
     (df['ACCT_TYP'].str.contains("L")) & 
     (df['LV_DMC_CTRY'].str.contains("GB")) & 
     (df['ROW_SRC_IND'].str.contains("PPSL")) & 
     (~(df['TXN_CCY'].str.contains("RUB"))) & 
     (df['IB_FLAG'].str.contains("N"))) |
    ((df['FRS_ACCOUNT_CLASS'].str.contains("OVDFT-LIAB")) & 
     (df['OPER_DPST_FLAG'].str.contains("Y")) & 
     (df['ACTG_UNIT_NM'].str.contains("Inventory Position Amount")) & 
     (df['ACCT_TYP'].str.contains("L")) & 
     (df['LV_DMC_CTRY'].str.contains("LU")) & 
     (df['ROW_SRC_IND'].str.contains("PPSL")))]

# %%
filtered_df.to_csv('result.csv',index = True)
